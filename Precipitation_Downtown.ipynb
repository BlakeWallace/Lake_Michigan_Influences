# %% [markdown]
# <font color = blue>Exploring precipitation in downtown Chicago.</font>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('data/Precipitation_data/Precipitation_downtown.csv')
df.head()
# Out:
#        STATION                   NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 1  US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 2  US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 3  US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 4  US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
#
#          DATE  PRCP PRCP_ATTRIBUTES  SNOW SNOW_ATTRIBUTES
# 0  2007-03-15  0.07             ,,N   NaN             NaN
# 1  2007-03-19  0.14             ,,N   0.0             ,,N
# 2  2007-03-20  0.00             ,,N   0.0             ,,N
# 3  2007-03-21  0.57             ,,N   0.0             ,,N
# 4  2007-03-22  0.36             ,,N   0.0             ,,N

# %%
df.shape
# Out:
# (3395, 10)

# %% [markdown]
# <font color = blue size = 5.5>Precipitation has no nulls</font>

# %%
df.isnull().sum()
# Out:
# STATION               0
# NAME                  0
# LATITUDE              0
# LONGITUDE             0
# ELEVATION             0
# DATE                  0
# PRCP                  0
# PRCP_ATTRIBUTES       0
# SNOW               1092
# SNOW_ATTRIBUTES    1092
# dtype: int64

# %%
df.dtypes
# Out:
# STATION             object
# NAME                object
# LATITUDE           float64
# LONGITUDE          float64
# ELEVATION          float64
# DATE                object
# PRCP               float64
# PRCP_ATTRIBUTES     object
# SNOW               float64
# SNOW_ATTRIBUTES     object
# dtype: object

# %%
df.PRCP_ATTRIBUTES.nunique()
# Out:
# 2

# %%
df.PRCP_ATTRIBUTES.value_counts()
# Out:
# ,,N     3186
# T,,N     209
# Name: PRCP_ATTRIBUTES, dtype: int64

# %%
plt.hist(df['PRCP']);

# %%
df[['PRCP', 'SNOW']].plot(kind='hist', x='PRCP');

# %%
df.dtypes
# Out:
# STATION             object
# NAME                object
# LATITUDE           float64
# LONGITUDE          float64
# ELEVATION          float64
# DATE                object
# PRCP               float64
# PRCP_ATTRIBUTES     object
# SNOW               float64
# SNOW_ATTRIBUTES     object
# dtype: object

# %%
df[df.SNOW.isnull() == True].head()
# Out:
#          STATION                   NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0    US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 182  US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 183  US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 184  US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 185  US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
#
#            DATE  PRCP PRCP_ATTRIBUTES  SNOW SNOW_ATTRIBUTES
# 0    2007-03-15  0.07             ,,N   NaN             NaN
# 182  2007-12-11  0.36             ,,N   NaN             NaN
# 183  2007-12-15  0.03             ,,N   NaN             NaN
# 184  2007-12-16  0.24             ,,N   NaN             NaN
# 185  2007-12-19  0.00             ,,N   NaN             NaN

# %%
df['PRCP'].nunique()
# Out:
# 132

# %%
df[['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'PRCP']]
# Out:
#           STATION                   NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0     US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 1     US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 2     US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 3     US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 4     US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 5     US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 6     US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 7     US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 8     US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 9     US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 10    US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# 11    US1ILCK0036  CHICAGO 4.7 NE, IL US    41.886    -87.621      191.1
# ...

# %%
df[['DATE', 'PRCP', 'SNOW']]
# Out:
#             DATE  PRCP  SNOW
# 0     2007-03-15  0.07   NaN
# 1     2007-03-19  0.14   0.0
# 2     2007-03-20  0.00   0.0
# 3     2007-03-21  0.57   0.0
# 4     2007-03-22  0.36   0.0
# 5     2007-03-27  0.00   0.0
# 6     2007-03-28  0.20   0.0
# 7     2007-04-05  0.02   0.0
# 8     2007-04-09  0.00   0.0
# 9     2007-04-10  0.00   0.0
# 10    2007-04-18  0.00   0.0
# 11    2007-04-19  0.00   0.0
# 12    2007-04-20  0.00   0.0
# 13    2007-04-23  0.00   0.0
# 14    2007-04-24  0.00   0.0
# 15    2007-04-28  0.01   0.0
# 16    2007-04-29  0.00   0.0
# 17    2007-04-30  0.21   0.0
# 18    2007-05-01  0.00   0.0
# 19    2007-05-02  0.00   0.0
# 20    2007-05-04  0.00   0.0
# 21    2007-05-07  0.00   0.0
# 22    2007-05-08  0.00   0.0
# 23    2007-05-09  0.00   0.0
# 24    2007-05-12  0.00   0.0
# 25    2007-05-13  0.00   0.0
# 26    2007-05-14  0.00   0.0
# 27    2007-05-15  0.00   0.0
# 28    2007-05-16  0.65   0.0
# 29    2007-05-19  0.00   0.0
# ...          ...   ...   ...
# ...

# %%
df['SNOW'].nunique()
# Out:
# 1

# %%
df['SNOW'].value_counts()
# Out:
# 0.0    2303
# Name: SNOW, dtype: int64

# %%
df['PRCP'].nunique()
# Out:
# 132

# %%
df['PRCP'].value_counts()
# Out:
# 0.00    2391
# 0.01      94
# 0.02      87
# 0.03      56
# 0.04      49
# 0.06      36
# 0.05      31
# 0.07      29
# 0.08      26
# 0.09      26
# 0.11      26
# 0.10      21
# 0.12      20
# 0.16      19
# 0.20      18
# 0.23      18
# 0.19      17
# 0.18      17
# 0.15      15
# 0.14      14
# 0.13      13
# 0.21      12
# 0.17      12
# 0.24      12
# 0.26      12
# 0.57      10
# 0.40       9
# 0.34       9
# 0.30       8
# 0.29       8
#         ...
# 1.49       1
# 1.30       1
# 1.72       1
# 5.00       1
# 1.27       1
# 0.75       1
# 1.02       1
# 4.06       1
# 2.54       1
# 1.63       1
# 4.23       1
# 0.64       1
# 1.45       1
# 1.79       1
# 2.13       1
# 1.34       1
# 0.70       1
# 1.05       1
# 1.13       1
# 1.85       1
# 0.68       1
# 3.10       1
# 1.53       1
# 1.98       1
# 1.47       1
# 0.92       1
# 2.10       1
# 1.84       1
# 2.79       1
# 4.22       1
# Name: PRCP, Length: 132, dtype: int64

# %%
precip = df[['DATE', 'NAME', 'PRCP']]

# %%
precip
# Out:
#             DATE                   NAME  PRCP
# 0     2007-03-15  CHICAGO 4.7 NE, IL US  0.07
# 1     2007-03-19  CHICAGO 4.7 NE, IL US  0.14
# 2     2007-03-20  CHICAGO 4.7 NE, IL US  0.00
# 3     2007-03-21  CHICAGO 4.7 NE, IL US  0.57
# 4     2007-03-22  CHICAGO 4.7 NE, IL US  0.36
# 5     2007-03-27  CHICAGO 4.7 NE, IL US  0.00
# 6     2007-03-28  CHICAGO 4.7 NE, IL US  0.20
# 7     2007-04-05  CHICAGO 4.7 NE, IL US  0.02
# 8     2007-04-09  CHICAGO 4.7 NE, IL US  0.00
# 9     2007-04-10  CHICAGO 4.7 NE, IL US  0.00
# 10    2007-04-18  CHICAGO 4.7 NE, IL US  0.00
# 11    2007-04-19  CHICAGO 4.7 NE, IL US  0.00
# 12    2007-04-20  CHICAGO 4.7 NE, IL US  0.00
# 13    2007-04-23  CHICAGO 4.7 NE, IL US  0.00
# 14    2007-04-24  CHICAGO 4.7 NE, IL US  0.00
# 15    2007-04-28  CHICAGO 4.7 NE, IL US  0.01
# 16    2007-04-29  CHICAGO 4.7 NE, IL US  0.00
# 17    2007-04-30  CHICAGO 4.7 NE, IL US  0.21
# 18    2007-05-01  CHICAGO 4.7 NE, IL US  0.00
# ...
