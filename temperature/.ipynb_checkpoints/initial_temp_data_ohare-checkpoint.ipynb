# %% [markdown]
# ### Data cleaning for the general ohare weather data.

# %% [markdown]
# #### data source
#
# https://www.ncdc.noaa.gov/cdo-web/search

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# reading in the dataframe

df = pd.read_csv('../data/temp_data/Ohare_FULL_temp_2000_2019.csv')

# %%
df.head()
# Out:
#        STATION                                        NAME  LATITUDE  \
# 0  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 1  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 2  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 3  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 4  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
#
#    LONGITUDE  ELEVATION        DATE   AWND AWND_ATTRIBUTES    FMTM  \
# 0   -87.9336      201.8  2000-01-01   7.38             ,,X   148.0
# 1   -87.9336      201.8  2000-01-02  13.87             ,,X  1537.0
# 2   -87.9336      201.8  2000-01-03  12.75             ,,X  1828.0
# 3   -87.9336      201.8  2000-01-04  13.42             ,,X   227.0
# 4   -87.9336      201.8  2000-01-05  11.18             ,,X  2017.0
#
#   FMTM_ATTRIBUTES  ...  WT19 WT19_ATTRIBUTES  WT21 WT21_ATTRIBUTES  WT22  \
# ...

# %%
df['class'] = df.NAME.apply(lambda x: 1 if 'CHI' in x else 0)

# %%
df[df['class'] == 1].tail(836)
# Out:
#           STATION                                        NAME  LATITUDE  \
# 6210  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6211  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6212  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6213  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6214  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6215  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6216  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6217  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6218  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6219  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6220  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6221  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# ...

# %%
df[df['class'] == 1].shape
# Out:
# (7046, 79)

# %%
# these are the 836 rows that containa TAVG
df[(df['class'] == 1) & (df['TMAX'] != '')].tail(836)
# Out:
#           STATION                                        NAME  LATITUDE  \
# 6210  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6211  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6212  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6213  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6214  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6215  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6216  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6217  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6218  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6219  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6220  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6221  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# ...

# %%
df.notnull().sum()
# Out:
# STATION            7046
# NAME               7046
# LATITUDE           7046
# LONGITUDE          7046
# ELEVATION          7046
# DATE               7046
# AWND               7045
# AWND_ATTRIBUTES    7045
# FMTM               4288
# FMTM_ATTRIBUTES    4288
# PGTM               4141
# PGTM_ATTRIBUTES    4141
# PRCP               7045
# PRCP_ATTRIBUTES    7045
# SNOW               7045
# SNOW_ATTRIBUTES    7045
# SNWD               6984
# SNWD_ATTRIBUTES    6984
# TAVG               4243
# TAVG_ATTRIBUTES    4243
# TMAX               7045
# TMAX_ATTRIBUTES    7045
# TMIN               7045
# TMIN_ATTRIBUTES    7045
# TSUN                753
# TSUN_ATTRIBUTES     753
# WDF2               7045
# WDF2_ATTRIBUTES    7045
# WDF5               7023
# WDF5_ATTRIBUTES    7023
#                    ...
# WT07_ATTRIBUTES      85
# WT08               1426
# WT08_ATTRIBUTES    1426
# WT09                 75
# WT09_ATTRIBUTES      75
# WT11                 26
# WT11_ATTRIBUTES      26
# ...

# %%
df.shape
# Out:
# (7046, 79)

# %%
df[(df['TMAX'].isnull() == False) & (df['TMIN'].isnull() == False)]['NAME'].value_counts()
# Out:
# CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    7045
# Name: NAME, dtype: int64

# %%
df[df['TAVG'].isnull() == False] #.NAME.value_counts()
# Out:
#           STATION                                        NAME  LATITUDE  \
# 0     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 1     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 2     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 3     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 4     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 5     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 7     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 8     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 9     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 10    USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 11    USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# ...

# %%
df = df[df['TAVG'].isnull() == False] #.NAME.value_counts()

# %%
df.shape
# Out:
# (4243, 79)

# %%
df.NAME.nunique()
# Out:
# 1

# %%
df
# Out:
#           STATION                                        NAME  LATITUDE  \
# 0     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 1     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 2     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 3     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 4     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 5     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 6     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 7     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 8     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 9     USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 10    USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 11    USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# ...
