# %% [markdown]
# ## Cleaning the daily temperature data for Ohare airport for the years 2000-2019.

# %% [markdown]
# ### Data source
#
# https://www.ncdc.noaa.gov/cdo-web/search

# %% [markdown]
# ### Data in the final dataset
#
# - TAVG - Average Temperature
# - TMAX - Maximum Temperature
# - TMIN - Minimum Temperature
# - AVG - average between the maximum and the minimum daily values
# - error - TAVG - AVG
# - LOC - Location

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Here we start with the full temp data from Ohare.

df100 = pd.read_csv('../data/temp_data/Ohare_FULL_temp_2000_2019.csv')
df100.shape
# Out:
# (7046, 78)

# %%
df100.head()
# Out:
#        STATION                                        NAME  LATITUDE  \
# 0  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 1  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 2  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 3  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 4  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
#
#    LONGITUDE  ELEVATION        DATE   AWND AWND_ATTRIBUTES    FMTM  \
# 0   -87.9336      201.8  2000-01-01   7.38             ,,X   148.0
# 1   -87.9336      201.8  2000-01-02  13.87             ,,X  1537.0
# 2   -87.9336      201.8  2000-01-03  12.75             ,,X  1828.0
# 3   -87.9336      201.8  2000-01-04  13.42             ,,X   227.0
# 4   -87.9336      201.8  2000-01-05  11.18             ,,X  2017.0
#
#   FMTM_ATTRIBUTES  ...  WT19 WT19_ATTRIBUTES  WT21 WT21_ATTRIBUTES  WT22  \
# 0             ,,X  ...   NaN             NaN   NaN             NaN   NaN
# 1             ,,X  ...   NaN             NaN   NaN             NaN   NaN
# 2             ,,X  ...   NaN             NaN   NaN             NaN   NaN
# 3             ,,X  ...   NaN             NaN   NaN             NaN   NaN
# 4             ,,X  ...   NaN             NaN   NaN             NaN   NaN
#
#   WT22_ATTRIBUTES  WV03 WV03_ATTRIBUTES  WV20 WV20_ATTRIBUTES
# 0             NaN   NaN             NaN   NaN             NaN
# 1             NaN   NaN             NaN   NaN             NaN
# 2             NaN   NaN             NaN   NaN             NaN
# 3             NaN   NaN             NaN   NaN             NaN
# 4             NaN   NaN             NaN   NaN             NaN
#
# [5 rows x 78 columns]

# %%
df100.tail()
# Out:
#           STATION                                        NAME  LATITUDE  \
# 7041  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 7042  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 7043  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 7044  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 7045  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
#
#       LONGITUDE  ELEVATION        DATE   AWND AWND_ATTRIBUTES  FMTM  \
# 7041   -87.9336      201.8  2019-04-12  16.55             ,,W   NaN
# 7042   -87.9336      201.8  2019-04-13  12.30             ,,W   NaN
# 7043   -87.9336      201.8  2019-04-14  18.12             ,,W   NaN
# 7044   -87.9336      201.8  2019-04-15   8.28             ,,W   NaN
# 7045   -87.9336      201.8  2019-04-16    NaN             NaN   NaN
#
#      FMTM_ATTRIBUTES  ...  WT19 WT19_ATTRIBUTES  WT21 WT21_ATTRIBUTES  WT22  \
# 7041             NaN  ...   NaN             NaN   NaN             NaN   NaN
# 7042             NaN  ...   NaN             NaN   NaN             NaN   NaN
# 7043             NaN  ...   NaN             NaN   NaN             NaN   NaN
# 7044             NaN  ...   NaN             NaN   NaN             NaN   NaN
# 7045             NaN  ...   NaN             NaN   NaN             NaN   NaN
#
#      WT22_ATTRIBUTES  WV03 WV03_ATTRIBUTES  WV20 WV20_ATTRIBUTES
# 7041             NaN   NaN             NaN   NaN             NaN
# 7042             NaN   NaN             NaN   NaN             NaN
# 7043             NaN   NaN             NaN   NaN             NaN
# 7044             NaN   NaN             NaN   NaN             NaN
# 7045             NaN   NaN             NaN   NaN             NaN
#
# [5 rows x 78 columns]

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 500

# %%
df100.head(5)
# Out:
#        STATION                                        NAME  LATITUDE  \
# 0  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 1  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 2  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 3  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
# 4  USW00094846  CHICAGO OHARE INTERNATIONAL AIRPORT, IL US    41.995
#
#    LONGITUDE  ELEVATION        DATE   AWND AWND_ATTRIBUTES    FMTM  \
# 0   -87.9336      201.8  2000-01-01   7.38             ,,X   148.0
# 1   -87.9336      201.8  2000-01-02  13.87             ,,X  1537.0
# 2   -87.9336      201.8  2000-01-03  12.75             ,,X  1828.0
# 3   -87.9336      201.8  2000-01-04  13.42             ,,X   227.0
# 4   -87.9336      201.8  2000-01-05  11.18             ,,X  2017.0
#
#   FMTM_ATTRIBUTES    PGTM PGTM_ATTRIBUTES  PRCP PRCP_ATTRIBUTES  SNOW  \
# 0             ,,X   134.0             ,,W  0.00       T,,0,2400   0.0
# 1             ,,X  1536.0             ,,W  0.01        ,,0,2400   0.0
# 2             ,,X  1248.0             ,,W  0.25        ,,0,2400   0.4
# 3             ,,X   210.0             ,,W  0.00       T,,0,2400   0.0
# 4             ,,X  2102.0             ,,W  0.00       T,,0,2400   0.0
#
#   SNOW_ATTRIBUTES  SNWD SNWD_ATTRIBUTES  TAVG TAVG_ATTRIBUTES  TMAX  \
# 0             ,,0   0.0            ,,0,  42.0             ,,W  48.0
# 1             ,,0   0.0            ,,0,  48.0             ,,W  60.0
# 2             ,,0   0.0            ,,0,  35.0             ,,W  38.0
# 3            T,,0   0.0            ,,0,  28.0             ,,W  33.0
# 4            T,,0   0.0            ,,0,  20.0             ,,W  26.0
#
#   TMAX_ATTRIBUTES  TMIN TMIN_ATTRIBUTES  TSUN TSUN_ATTRIBUTES   WDF2  \
# 0             ,,0  35.0             ,,0   NaN             NaN  200.0
# 1             ,,0  35.0             ,,0   NaN             NaN  240.0
# 2             ,,0  32.0             ,,0   NaN             NaN   30.0
# 3             ,,0  23.0             ,,0   NaN             NaN  320.0
# 4             ,,0  13.0             ,,0   NaN             NaN  170.0
#
#   WDF2_ATTRIBUTES   WDF5 WDF5_ATTRIBUTES  WESD WESD_ATTRIBUTES  WSF2  \
# 0             ,,X  210.0             ,,X   0.0             ,,0  17.9
# 1             ,,X  230.0             ,,X   0.0             ,,0  25.9
# 2             ,,X   80.0             ,,X   0.0             ,,0  17.9
# 3             ,,X  300.0             ,,X   0.0             ,,0  21.9
# 4             ,,X  160.0             ,,X   0.0             ,,0  23.0
#
#   WSF2_ATTRIBUTES  WSF5 WSF5_ATTRIBUTES  WT01 WT01_ATTRIBUTES  WT02  \
# 0             ,,X  23.9             ,,X   NaN             NaN   NaN
# 1             ,,X  36.9             ,,X   1.0             ,,0   NaN
# 2             ,,X  25.1             ,,X   1.0             ,,0   NaN
# 3             ,,X  29.1             ,,X   1.0             ,,0   NaN
# 4             ,,X  25.9             ,,X   1.0             ,,0   NaN
#
#   WT02_ATTRIBUTES  WT03 WT03_ATTRIBUTES  WT04 WT04_ATTRIBUTES  WT05  \
# 0             NaN   NaN             NaN   NaN             NaN   NaN
# 1             NaN   NaN             NaN   NaN             NaN   NaN
# 2             NaN   NaN             NaN   NaN             NaN   NaN
# 3             NaN   NaN             NaN   NaN             NaN   NaN
# 4             NaN   NaN             NaN   NaN             NaN   NaN
#
#   WT05_ATTRIBUTES  WT06 WT06_ATTRIBUTES  WT07 WT07_ATTRIBUTES  WT08  \
# 0             NaN   NaN             NaN   NaN             NaN   NaN
# 1             NaN   NaN             NaN   NaN             NaN   NaN
# 2             NaN   NaN             NaN   NaN             NaN   NaN
# 3             NaN   NaN             NaN   NaN             NaN   NaN
# 4             NaN   NaN             NaN   NaN             NaN   NaN
#
#   WT08_ATTRIBUTES  WT09 WT09_ATTRIBUTES  WT11 WT11_ATTRIBUTES  WT13  \
# 0             NaN   NaN             NaN   NaN             NaN   NaN
# 1             NaN   NaN             NaN   NaN             NaN   1.0
# 2             NaN   NaN             NaN   NaN             NaN   1.0
# 3             NaN   NaN             NaN   NaN             NaN   1.0
# 4             NaN   NaN             NaN   NaN             NaN   1.0
#
#   WT13_ATTRIBUTES  WT14 WT14_ATTRIBUTES  WT15 WT15_ATTRIBUTES  WT16  \
# 0             NaN   NaN             NaN   NaN             NaN   1.0
# 1             ,,X   1.0             ,,X   NaN             NaN   1.0
# 2             ,,X   1.0             ,,X   NaN             NaN   1.0
# 3             ,,X   NaN             NaN   NaN             NaN   NaN
# 4             ,,X   NaN             NaN   NaN             NaN   NaN
#
#   WT16_ATTRIBUTES  WT17 WT17_ATTRIBUTES  WT18 WT18_ATTRIBUTES  WT19  \
# 0             ,,0   NaN             NaN   NaN             NaN   NaN
# 1             ,,0   NaN             NaN   NaN             NaN   NaN
# 2             ,,0   NaN             NaN   1.0             ,,0   NaN
# 3             NaN   NaN             NaN   1.0             ,,0   NaN
# 4             NaN   NaN             NaN   1.0             ,,0   NaN
#
#   WT19_ATTRIBUTES  WT21 WT21_ATTRIBUTES  WT22 WT22_ATTRIBUTES  WV03  \
# 0             NaN   NaN             NaN   NaN             NaN   NaN
# 1             NaN   NaN             NaN   NaN             NaN   NaN
# 2             NaN   NaN             NaN   NaN             NaN   NaN
# 3             NaN   NaN             NaN   NaN             NaN   NaN
# 4             NaN   NaN             NaN   NaN             NaN   NaN
#
#   WV03_ATTRIBUTES  WV20 WV20_ATTRIBUTES
# 0             NaN   NaN             NaN
# 1             NaN   NaN             NaN
# 2             NaN   NaN             NaN
# 3             NaN   NaN             NaN
# 4             NaN   NaN             NaN

# %%
df100.isnull().sum()
# Out:
# STATION               0
# NAME                  0
# LATITUDE              0
# LONGITUDE             0
# ELEVATION             0
# DATE                  0
# AWND                  1
# AWND_ATTRIBUTES       1
# FMTM               2758
# FMTM_ATTRIBUTES    2758
# PGTM               2905
# PGTM_ATTRIBUTES    2905
# PRCP                  1
# PRCP_ATTRIBUTES       1
# SNOW                  1
# SNOW_ATTRIBUTES       1
# SNWD                 62
# SNWD_ATTRIBUTES      62
# TAVG               2803
# TAVG_ATTRIBUTES    2803
# TMAX                  1
# TMAX_ATTRIBUTES       1
# TMIN                  1
# TMIN_ATTRIBUTES       1
# TSUN               6293
# TSUN_ATTRIBUTES    6293
# WDF2                  1
# WDF2_ATTRIBUTES       1
# WDF5                 23
# WDF5_ATTRIBUTES      23
# WESD               3028
# WESD_ATTRIBUTES    3028
# WSF2                  1
# WSF2_ATTRIBUTES       1
# WSF5                 23
# WSF5_ATTRIBUTES      23
# WT01               4152
# WT01_ATTRIBUTES    4152
# WT02               6828
# WT02_ATTRIBUTES    6828
# WT03               6304
# WT03_ATTRIBUTES    6304
# WT04               6926
# WT04_ATTRIBUTES    6926
# WT05               6696
# WT05_ATTRIBUTES    6696
# WT06               6980
# WT06_ATTRIBUTES    6980
# WT07               6961
# WT07_ATTRIBUTES    6961
# WT08               5620
# WT08_ATTRIBUTES    5620
# WT09               6971
# WT09_ATTRIBUTES    6971
# WT11               7020
# WT11_ATTRIBUTES    7020
# WT13               5183
# WT13_ATTRIBUTES    5183
# WT14               6675
# WT14_ATTRIBUTES    6675
# WT15               7027
# WT15_ATTRIBUTES    7027
# WT16               5084
# WT16_ATTRIBUTES    5084
# WT17               7023
# WT17_ATTRIBUTES    7023
# WT18               6270
# WT18_ATTRIBUTES    6270
# WT19               7040
# WT19_ATTRIBUTES    7040
# WT21               7019
# WT21_ATTRIBUTES    7019
# WT22               6967
# WT22_ATTRIBUTES    6967
# WV03               6978
# WV03_ATTRIBUTES    6978
# WV20               7045
# WV20_ATTRIBUTES    7045
# dtype: int64

# %%
df_Ohare = df100[['DATE', 'TAVG', 'TMAX', 'TMIN']]

# %%
df100[['DATE', 'TAVG', 'TMAX', 'TMIN']][df100['TAVG'].isnull() == True].head()
# Out:
#             DATE  TAVG  TMAX  TMIN
# 85    2000-03-26   NaN  68.0  36.0
# 86    2000-03-27   NaN  56.0  38.0
# 437   2001-03-13   NaN  42.0  31.0
# 2039  2005-08-01   NaN  93.0  69.0
# 2040  2005-08-02   NaN  92.0  65.0

# %%
df100[['DATE', 'TAVG', 'TMAX', 'TMIN']][df100['TAVG'].isnull() == True].head()
# Out:
#             DATE  TAVG  TMAX  TMIN
# 85    2000-03-26   NaN  68.0  36.0
# 86    2000-03-27   NaN  56.0  38.0
# 437   2001-03-13   NaN  42.0  31.0
# 2039  2005-08-01   NaN  93.0  69.0
# 2040  2005-08-02   NaN  92.0  65.0

# %%
df_Ohare['AVG'] = (df_Ohare['TMAX'] + df_Ohare['TMIN']) * 0.5
# Out:
# /Users/blakewallace/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_Ohare['error'] = df_Ohare['TAVG'] - df_Ohare['AVG']
df_Ohare.head()
# Out:
# /Users/blakewallace/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          DATE  TAVG  TMAX  TMIN   AVG  error
# 0  2000-01-01  42.0  48.0  35.0  41.5    0.5
# 1  2000-01-02  48.0  60.0  35.0  47.5    0.5
# 2  2000-01-03  35.0  38.0  32.0  35.0    0.0
# 3  2000-01-04  28.0  33.0  23.0  28.0    0.0
# 4  2000-01-05  20.0  26.0  13.0  19.5    0.5

# %%
df_Ohare.dtypes
# Out:
# DATE      object
# TAVG     float64
# TMAX     float64
# TMIN     float64
# AVG      float64
# error    float64
# dtype: object

# %%
df_Ohare['LOC'] = 'ohare'
df_Ohare.head()
# Out:
# /Users/blakewallace/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          DATE  TAVG  TMAX  TMIN   AVG  error    LOC
# 0  2000-01-01  42.0  48.0  35.0  41.5    0.5  ohare
# 1  2000-01-02  48.0  60.0  35.0  47.5    0.5  ohare
# 2  2000-01-03  35.0  38.0  32.0  35.0    0.0  ohare
# 3  2000-01-04  28.0  33.0  23.0  28.0    0.0  ohare
# 4  2000-01-05  20.0  26.0  13.0  19.5    0.5  ohare

# %%
# saving the dataframe
df_Ohare.to_csv('../data/temp_data/ohare_temp_2000_2019.csv', index=False)

# %%
df_Ohare['DATE'] = pd.to_datetime(df_Ohare['DATE'])
# Out:
# /Users/blakewallace/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_Ohare.dtypes
# Out:
# DATE     datetime64[ns]
# TAVG            float64
# TMAX            float64
# TMIN            float64
# AVG             float64
# error           float64
# LOC              object
# dtype: object
