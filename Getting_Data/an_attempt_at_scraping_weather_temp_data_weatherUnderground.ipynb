# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url_1_1_2019 = 'https://www.wunderground.com/history/daily/KORD/date/2019-1-1?req_city=Chicago&req_state=IL&req_statename=Illinois&reqdb.zip=60290&reqdb.magic=1&reqdb.wmo=99999'


res = requests.get(url_1_1_2019)

# %%
res.status_code
# Out:
# 200

# %%
res
# Out:
# <Response [200]>

# %%
res.content
# Out:
# b'<!DOCTYPE html><html><head>\n  <title>Des Plaines, IL History | Weather Underground</title>\n  <meta charset="utf-8" />\n  <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n  <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1" />\n  <meta name="rating" content="general" />\n  <meta name="referrer" content="no-referrer-when-downgrade" />\n  <meta name="apple-itunes-app" content="app-id=486154808, affiliate-data=at=1010lrYB&ct=website_wu" />\n  <meta name="fb_app_id" content="325331260891611" />\n  <meta name="fb_channel_url" content="width=device-width, initial-scale=1, maximum-scale=1" />\n  <meta property="og:site_name" content="Weather Underground" />\n  <meta property="og:type" content="article" />\n  <meta name="description" content="Weather Underground provides local & long range weather forecasts, weather reports, maps & tropical weather conditions for locations worldwide." />\n  <meta name="wui-member-logged-in" content="false
# ...

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %%
soup.keys

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Des Plaines, IL History | Weather Underground
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="general" name="rating"/>
#   <meta content="no-referrer-when-downgrade" name="referrer"/>
#   <meta content="app-id=486154808, affiliate-data=at=1010lrYB&amp;ct=website_wu" name="apple-itunes-app"/>
#   <meta content="325331260891611" name="fb_app_id"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="fb_channel_url"/>
#   <meta content="Weather Underground" property="og:site_name"/>
#   <meta content="article" property="og:type"/>
#   <meta content="Weather Underground provides local &amp; long range weather forecasts, weather reports, maps &amp; tropical weather conditions for locations worldwide." name="description"/>
# ...

# %%
print(soup.title)
print(soup.title.name)
print(soup.title.text)
print(soup.title.string)
print(soup.meta['charset'])
print(soup.script.name)
print(type(soup.script))
print(type(soup.script.text))
print(soup.script)
# Out:
# <title>Des Plaines, IL History | Weather Underground</title>
# title
# Des Plaines, IL History | Weather Underground
# Des Plaines, IL History | Weather Underground
# utf-8
# script
# <class 'bs4.element.Tag'>
# <class 'str'>
# <script>
#   //<![CDATA[
# ...

# %%
print(soup.find('div', attrs={'class':'tablesaw-sortable'}))
# Out:
# None

# %%
print(soup.div.attrs)
# Out:
# {'_ngcontent-c34': '', 'class': ['content-wrap', 'right-side-nav']}

# %%
print(soup.div['class'])
# Out:
# ['content-wrap', 'right-side-nav']

# %%
soup.find_all('div', {'_ngcontent-c34': ''})
# Out:
# [<div _ngcontent-c34="" class="content-wrap right-side-nav">
#  <div class="region-header">
#  <ad-mw-position-1>
#  <div class="top-banner ad-wrap ad-mobile" id="position-1-banner-ad-browser">
#  <div id="MW_Position1"></div>
#  </div>
#  </ad-mw-position-1>
#  <header-component><site-notice _nghost-c3=""><!-- --></site-notice>
#  <header-menu-mobile><nav class="sidebar" id="feature-menu-mobile">
#  <div class="sidebar-wrapper">
#  <ul class="side-main-nav nav-bar">
#  <!-- --><li>
#  <a href="/signup">
#  <i class="fi-torso sidebar-icon"></i>Log in / Join
#          </a>
#  </li>
#  <!-- -->
#  <li class="gotMore">
#  <a href="data.asp#">
#  <i class="fi-widget sidebar-icon"></i> Settings
#          </a>
#  <ul class="sideSubNav">
#  <li class="sideGoBack"><a href="javascript:void(0);">Settings</a></li>
#  <li>
#  <header-user-settings><div class="hide-for-small">
#  <button class="wu-settings">
#  <i class="fi-widget"></i>
#  </button>
#  </div>
#  </header-user-settings>
# ...

# %%
soup.find_all('span', {'class':'wu-value wu-value-to'})
# Out:
# [<span _ngcontent-c10="" class="wu-value wu-value-to" style="color:#71bc3c;">44</span>]

# %%
soup.span['class']
# Out:
# ['fi-list-wrap']

# %%
soup.span
# Out:
# <span class="fi-list-wrap"><i class="fi-list"></i></span>

# %%
soup.find_all('span', {'class': 'subheading'})
# Out:
# [<span _ngcontent-c14="" class="subheading">Elev <strong _ngcontent-c14="">0</strong>
#  <strong _ngcontent-c14="">41.98</strong> °N,
#      <strong _ngcontent-c14="">87.91</strong> °W
#    </span>]

# %%
soup.find_all('strong')
# Out:
# [<strong _ngcontent-c14="">0</strong>,
#  <strong _ngcontent-c14="">41.98</strong>,
#  <strong _ngcontent-c14="">87.91</strong>]

# %%
soup.find('strong', {'_ngcontent-c14':''}).text
# Out:
# '0'

# %%
for i in range(len(soup.find_all('strong'))):
    print(soup.find_all('strong')[i].text)
# Out:
# 0
# 41.98
# 87.91

# %%
soup.find_all('span', {'_ngcontent-c10':'', 'class': 'wu-value wu-value-to'})[0].text
# Out:
# '44'

# %%
soup.th.attrs
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-21f0c1ded4ce> in <module>
# ----> 1 soup.th.attrs
#
# AttributeError: 'NoneType' object has no attribute 'attrs'

# %%
ulist = soup.find('ul') # return the _first_ <ul>
for list_item in ulist.find_all('li'):    # return _all_ matches, <li>
    print(list_item.text)
# Out:
# Log in / Join
#
#
#
#
#  Settings
#
#
# Settings
#
#
#
#
#
#
#
#
#
#
# Settings
#
#
#
#
#
#
#
#
#
# Sensor Network
#
# Sensor Network
# Weather Station Network
# PWS Buying Guide
# Connect a Weather Station
# Connect a Webcam
#
#
# Sensor Network
# Weather Station Network
# PWS Buying Guide
# Connect a Weather Station
# Connect a Webcam
#
# Maps & Radar
#
# Maps & Radar
# WunderMap
# Interactive Radar
# Interactive Satellite
# Radar Maps
# Forecast Maps
# Full Maps Catalog
#
#
# Maps & Radar
# WunderMap
# Interactive Radar
# Interactive Satellite
# Radar Maps
# Forecast Maps
# Full Maps Catalog
#
# Severe Weather
#
# Severe Weather
# Hurricane & Tropical Cyclones
# U.S. Severe Weather Map
# Convective Outlook
# Wildfires
# Preparedness
# Email Alerts
#
#
# Severe Weather
# Hurricane & Tropical Cyclones
# U.S. Severe Weather Map
# Convective Outlook
# Wildfires
# Preparedness
# Email Alerts
#
# News & Blogs
#
# News & Blogs
# Category 6
# News Stories
# Videos
# Weather Infographics
# ...

# %%
# <a href="https://www.google.com/">
a_list = soup.find_all('a')
first_a = a_list[0]    # access the results like a list
link = first_a['href'] # access attributes of an element like a dict
print(first_a)
print(link)
# Out:
# <a href="/signup">
# <i class="fi-torso sidebar-icon"></i>Log in / Join
#         </a>
# /signup

# %%
#<div class="divvy-it-up" id="foobar">
#<p id="layer1">I'm in a div.  Yeah!</p>
#<div>
#<p id="layer2">I'm in a div, too!</p>
#</div>
#</div>

div_results = soup.body.find_all('div', 
                       {'id':'foobar', 'class':'divvy-it-up'})
div_results[0].find('p', {'id':'layer2'}).text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-5d811d786363> in <module>
#       8 div_results = soup.body.find_all('div',
#       9                        {'id':'foobar', 'class':'divvy-it-up'})
# ---> 10 div_results[0].find('p', {'id':'layer2'}).text
#
# IndexError: list index out of range

# %%
# This code collects the titles, links and urls for DataTau's homepage

# List to store results
results_list = []

# Get all the <td class="title"... elements
all_td = soup.find_all('td', {'class':'title'})
for element in all_td:
    # start a dictionary to store this item's data
    result = {}
    
    # get the title and full link/url
    a_href = element.find('a')
    if a_href:
        result['title'] = a_href.text   # element text
        result['link'] = a_href['href'] # href link
        
    # get the url domain
    span = element.find('span', {'class':'comhead'})
    if span:
        result['url'] = span.text.strip()[1:-1]
        
    # only store "full" rows of data
    if len(result) == 3:
        results_list.append(result)
        
results_list
# Out:
# []

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Des Plaines, IL History | Weather Underground
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="general" name="rating"/>
#   <meta content="no-referrer-when-downgrade" name="referrer"/>
#   <meta content="app-id=486154808, affiliate-data=at=1010lrYB&amp;ct=website_wu" name="apple-itunes-app"/>
#   <meta content="325331260891611" name="fb_app_id"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="fb_channel_url"/>
#   <meta content="Weather Underground" property="og:site_name"/>
#   <meta content="article" property="og:type"/>
#   <meta content="Weather Underground provides local &amp; long range weather forecasts, weather reports, maps &amp; tropical weather conditions for locations worldwide." name="description"/>
# ...

# %%
len(soup.find_all('span'))
# Out:
# 28

# %%
for row in soup.find_all('span'):
    print(row.text)
# Out:
# Elev 0
# 41.98 °N,
#     87.91 °W
#
#
#
#
#
# 44
# F
#
#
#
#
# 44
#
# F
#
#
#
# |
# Report
#
# Report Station
# Thank you for reporting this station. We will review the data in question.
#
#
# You are about to report this weather station for bad data. Please select the information that is incorrect.
#
#
#
# Temperature
#
#
#
# Pressure
#
#
#
# Wind
#
#
#
# Forecast
#
#
#
# Station Offline
#
#
#
# Send Report
#
#
#
#
# |
# |
#
#               Today
#
#
# Hourly Forecast
# Hourly
#
# Hourly Forecast
# Hourly
#
# 10-Day Forecast
# 10-Day
#
# 10-Day Forecast
# 10-Day
#
#               Calendar
#
#
#               History
#
#
#               Wundermap
#
# Today
# Hourly
# 10-Day
# Calendar
# History
# Wundermap
